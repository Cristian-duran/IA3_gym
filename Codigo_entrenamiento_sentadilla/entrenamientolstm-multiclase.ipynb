# %%
from typing import Sequence
import numpy as np
import pandas as pd
from keras.models import Sequential
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from keras.layers import LSTM, Dropout, Dense, BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
caderas_incorrectosdf = pd.read_csv("D:/InteligenciaArtificial3/dataset_imagenes/caderas_incorrectos.txt")
caderas_correctosdf = pd.read_csv("D:/InteligenciaArtificial3/dataset_imagenes/caderas_correctos.txt")
rodillas_incorrectosdf = pd.read_csv("D:/InteligenciaArtificial3/dataset_imagenes/rodillas_incorrectos.txt")
rodillas_correctosdf = pd.read_csv("D:/InteligenciaArtificial3/dataset_imagenes/rodillas_correctos.txt")

print("el tamaño de :",len(caderas_incorrectosdf))
print("el tamaño de :",len(caderas_correctosdf))
print("el tamaño de :",len(rodillas_incorrectosdf))
print("el tamaño de :",len(rodillas_correctosdf))

X = []
y = []
no_of_timesteps = 60

datasets = caderas_incorrectosdf.iloc[:,1:].values
n_samples = len(datasets)
for i in range(no_of_timesteps, n_samples):
    X.append(datasets[i-no_of_timesteps:i,:])
    y.append(0)

datasets = caderas_correctosdf.iloc[:,1:].values
n_samples = len(datasets)
#print(n_samples)
for i in range(no_of_timesteps, n_samples):
    X.append(datasets[i-no_of_timesteps:i,:])
    y.append(1)

datasets = rodillas_incorrectosdf.iloc[:,1:].values
n_samples = len(datasets)
for i in range(no_of_timesteps, n_samples):
    X.append(datasets[i-no_of_timesteps:i,:])
    y.append(2)

datasets = rodillas_correctosdf.iloc[:,1:].values
n_samples = len(datasets)
#print(n_samples)
for i in range(no_of_timesteps, n_samples):
    X.append(datasets[i-no_of_timesteps:i,:])
    y.append(3)

X, y = np.array(X), np.array(y)
print("Total de Datos",len(X),len(y))
print(X.shape, y.shape)

# Dividir los datos en conjunto de entrenamiento+validación y conjunto de prueba
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Dividir los datos restantes en conjunto de entrenamiento y conjunto de validación
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.15, random_state=42)  # 0.25 x 0.8 = 0.2

# Imprimir las formas de los conjuntos resultantes
print("entrenamiento shape:", X_train.shape)
print("validacion shape:", X_val.shape)
print("prueba shape:", X_test.shape)
# Out:
# el tamaño de : 11328
# el tamaño de : 11209
# el tamaño de : 11196
# el tamaño de : 11450
# Total de Datos 44943 44943
# (44943, 60, 34) (44943,)
# entrenamiento shape: (34380, 60, 34)
# validacion shape: (6068, 60, 34)
# prueba shape: (4495, 60, 34)

# %%
print(len(X_train))
print(y_train.shape)
print(X_test.shape)
# Out:
# 34380
# (34380,)
# (4495, 60, 34)

# %%
model2 = Sequential()
model2.add(LSTM(units=64, return_sequences=True, dropout=0.1, recurrent_dropout=0.1, input_shape=(X.shape[1], X.shape[2])))
model2.add(Dropout(0.2))
model2.add(LSTM(units=128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))
model2.add(Dropout(0.2))
model2.add(LSTM(units=64, return_sequences=False, dropout=0.1, recurrent_dropout=0.1))
model2.add(Dropout(0.2))
model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(units=4, activation='softmax'))
model2.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\USUARIO\anaconda3\envs\IA_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import matplotlib.pyplot as plt

callbacks = [
    EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5, min_lr=1e-6)
]

history = model2.fit(X_train, y_train, epochs=70, batch_size=32, callbacks=callbacks, validation_data=(X_val, y_val))

# Graficar la pérdida
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Pérdida durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

# Graficar la precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Precisión de entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión de validación')
plt.title('Precisión durante el entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

plt.show()
# Out:
# Epoch 1/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 89s 77ms/step - accuracy: 0.6352 - loss: 0.7073 - val_accuracy: 0.7080 - val_loss: 0.4501 - learning_rate: 0.0010
# Epoch 2/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.7122 - loss: 0.4805 - val_accuracy: 0.7388 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 3/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.7638 - loss: 0.4516 - val_accuracy: 0.7576 - val_loss: 0.4679 - learning_rate: 0.0010
# Epoch 4/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 75s 70ms/step - accuracy: 0.7808 - loss: 0.4112 - val_accuracy: 0.8446 - val_loss: 0.3259 - learning_rate: 0.0010
# Epoch 5/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.8298 - loss: 0.3633 - val_accuracy: 0.9616 - val_loss: 0.1305 - learning_rate: 0.0010
# Epoch 6/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.8819 - loss: 0.2845 - val_accuracy: 0.9426 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 7/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 73s 68ms/step - accuracy: 0.9069 - loss: 0.2401 - val_accuracy: 0.8958 - val_loss: 0.1984 - learning_rate: 0.0010
# Epoch 8/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.9147 - loss: 0.2260 - val_accuracy: 0.9746 - val_loss: 0.0828 - learning_rate: 0.0010
# Epoch 9/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 74s 68ms/step - accuracy: 0.9302 - loss: 0.1895 - val_accuracy: 0.9540 - val_loss: 0.1088 - learning_rate: 0.0010
# Epoch 10/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.9344 - loss: 0.1794 - val_accuracy: 0.9845 - val_loss: 0.0619 - learning_rate: 0.0010
# Epoch 11/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 90s 84ms/step - accuracy: 0.9389 - loss: 0.1672 - val_accuracy: 0.9830 - val_loss: 0.0466 - learning_rate: 0.0010
# Epoch 12/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 89s 82ms/step - accuracy: 0.9496 - loss: 0.1394 - val_accuracy: 0.9670 - val_loss: 0.0748 - learning_rate: 0.0010
# Epoch 13/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 88s 82ms/step - accuracy: 0.9614 - loss: 0.1118 - val_accuracy: 0.9825 - val_loss: 0.0477 - learning_rate: 0.0010
# Epoch 14/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 87s 81ms/step - accuracy: 0.9619 - loss: 0.1023 - val_accuracy: 0.9951 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 15/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 89s 83ms/step - accuracy: 0.9721 - loss: 0.0879 - val_accuracy: 0.9931 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 16/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 90s 83ms/step - accuracy: 0.9764 - loss: 0.0697 - val_accuracy: 0.9969 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 17/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 96s 89ms/step - accuracy: 0.9760 - loss: 0.0691 - val_accuracy: 0.9970 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 18/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 85s 79ms/step - accuracy: 0.9838 - loss: 0.0481 - val_accuracy: 0.9990 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 19/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.9842 - loss: 0.0481 - val_accuracy: 0.9820 - val_loss: 0.0477 - learning_rate: 0.0010
# Epoch 20/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 71ms/step - accuracy: 0.9793 - loss: 0.0680 - val_accuracy: 0.9984 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 21/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.9879 - loss: 0.0383 - val_accuracy: 0.9982 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 22/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9881 - loss: 0.0355 - val_accuracy: 0.9995 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 23/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.9909 - loss: 0.0262 - val_accuracy: 0.9998 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 24/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.9897 - loss: 0.0314 - val_accuracy: 0.9903 - val_loss: 0.0189 - learning_rate: 0.0010
# Epoch 25/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 77s 72ms/step - accuracy: 0.9916 - loss: 0.0272 - val_accuracy: 0.9987 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 26/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9929 - val_loss: 0.0203 - learning_rate: 0.0010
# Epoch 27/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9919 - loss: 0.0268 - val_accuracy: 0.9998 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 28/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9916 - loss: 0.0283 - val_accuracy: 0.9982 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 29/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 72ms/step - accuracy: 0.9956 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 1.5053e-04 - learning_rate: 3.0000e-04
# Epoch 30/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9972 - loss: 0.0090 - val_accuracy: 0.9998 - val_loss: 4.3038e-04 - learning_rate: 3.0000e-04
# Epoch 31/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9975 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 1.8390e-04 - learning_rate: 3.0000e-04
# Epoch 32/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9971 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 1.5459e-04 - learning_rate: 3.0000e-04
# Epoch 33/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9974 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 5.3636e-05 - learning_rate: 3.0000e-04
# Epoch 34/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9975 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 4.5046e-04 - learning_rate: 3.0000e-04
# Epoch 35/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 4.7965e-05 - learning_rate: 9.0000e-05
# Epoch 36/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 5.3558e-06 - learning_rate: 9.0000e-05
# Epoch 37/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 78s 73ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 8.8229e-06 - learning_rate: 9.0000e-05
# Epoch 38/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 1.1359e-05 - learning_rate: 9.0000e-05
# Epoch 39/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9985 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 4.4930e-05 - learning_rate: 9.0000e-05
# Epoch 40/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 3.1837e-05 - learning_rate: 9.0000e-05
# Epoch 41/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9988 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 1.5960e-05 - learning_rate: 2.7000e-05
# Epoch 42/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 74ms/step - accuracy: 0.9984 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 1.3822e-05 - learning_rate: 2.7000e-05
# Epoch 43/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 9.0145e-06 - learning_rate: 2.7000e-05
# Epoch 44/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 74ms/step - accuracy: 0.9984 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 5.0438e-06 - learning_rate: 2.7000e-05
# Epoch 45/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9983 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 2.9291e-06 - learning_rate: 2.7000e-05
# Epoch 46/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 2.8617e-06 - learning_rate: 8.1000e-06
# Epoch 47/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 3.5007e-06 - learning_rate: 8.1000e-06
# Epoch 48/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 79s 74ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 3.9774e-06 - learning_rate: 8.1000e-06
# Epoch 49/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9984 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 2.3142e-06 - learning_rate: 8.1000e-06
# Epoch 50/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9983 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 2.3721e-06 - learning_rate: 8.1000e-06
# Epoch 51/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.9986 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 1.9937e-06 - learning_rate: 2.4300e-06
# Epoch 52/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 74ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 2.4551e-06 - learning_rate: 2.4300e-06
# Epoch 53/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 2.7201e-06 - learning_rate: 2.4300e-06
# Epoch 54/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.9987 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 2.8377e-06 - learning_rate: 2.4300e-06
# Epoch 55/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.9988 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 2.5908e-06 - learning_rate: 2.4300e-06
# Epoch 56/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 2.4194e-06 - learning_rate: 1.0000e-06
# Epoch 57/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 2.2775e-06 - learning_rate: 1.0000e-06
# Epoch 58/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 2.1426e-06 - learning_rate: 1.0000e-06
# Epoch 59/70
# 1075/1075 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 2.1883e-06 - learning_rate: 1.0000e-06

# %%
evaluation = model2.evaluate(X_test, y_test)
print("Resultado de la evaluación:")
print("Loss:", evaluation[0])
print("Accuracy:", evaluation[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 evaluation = model2.evaluate(X_test, y_test)
#       2 print("Resultado de la evaluación:")
#       3 print("Loss:", evaluation[0])
#
# NameError: name 'model2' is not defined

# %%
model2.save("D:/InteligenciaArtificial3/Modelos/pruebas_multi/lstm3-model3sen.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import load_model

# Cargar el modelo
loaded_model = load_model("D:/InteligenciaArtificial3/Modelos/pruebas_multi/lstm3-model3sen.h5")

# Verificar que el modelo se ha cargado correctamente
loaded_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 32)         │         8,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,278 (196.40 KB)
#  Trainable params: 50,212 (196.14 KB)
#  Non-trainable params: 64 (256.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,multilabel_confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

# Suponiendo que tienes los nombres de las clases en una lista
class_names = ['caderas_incorrectos 0', 'caderas_correctos 1', 'rodillas_incorrectos 2', 'rodillas_correctos 3']  # Reemplaza con los nombres de tus clases

# Paso 1: Realizar predicciones
y_pred = loaded_model.predict(X_val)

# Paso 2: Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(y_pred, axis=1)

# Paso 3: Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_val, y_pred_classes)

# Paso 4: Graficar la matriz de confusión con etiquetas
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)

plt.title('Matriz de Confusión')
plt.show()
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,multilabel_confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

# Suponiendo que tienes los nombres de las clases en una lista
class_names = ['caderas_incorrectos 0', 'caderas_correctos 1', 'rodillas_incorrectos 2', 'rodillas_correctos 3']  # Reemplaza con los nombres de tus clases

# Paso 1: Realizar predicciones
y_pred = model2.predict(X_val)

# Paso 2: Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(y_pred, axis=1)

# Paso 3: Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_val, y_pred_classes)

# Paso 4: Graficar la matriz de confusión con etiquetas
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)

plt.title('Matriz de Confusión')
plt.show()
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step

# %%
import numpy as np
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Paso 1: Realizar predicciones
y_pred = model2.predict(X_val)

# Paso 2: Convertir las predicciones en etiquetas de clase
y_pred_classes = np.argmax(y_pred, axis=1)

# Paso 3: Obtener el reporte de clasificación
report = classification_report(y_val, y_pred_classes)

# Paso 4: Imprimir el reporte de clasificación
print("Métricas de Evaluación:\n")
#print(report)

# Si deseas mostrar el reporte en una figura de matplotlib
plt.figure(figsize=(10, 5))
plt.text(0.01, 1.1, str(report), {'fontsize': 10}, fontproperties='monospace') 
plt.axis('off')
plt.show()
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# Métricas de Evaluación:

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, roc_curve, roc_auc_score, f1_score
import matplotlib.pyplot as plt

# Predicciones del modelo
y_pred = model2.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicciones como etiquetas de clase

# Matriz de confusión
conf_matrix = confusion_matrix(y_val, y_pred_classes)

# Mostrar la matriz de confusión
print("Matriz de Confusión:")
print(conf_matrix)

# Tasa de Falsos Positivos (FPR) por clase
fpr_dict = {}
for i in range(len(conf_matrix)):
    tn = np.sum(conf_matrix) - np.sum(conf_matrix[i, :]) - np.sum(conf_matrix[:, i]) + conf_matrix[i, i]
    fp = np.sum(conf_matrix[:, i]) - conf_matrix[i, i]
    fpr_dict[f"Clase {i}"] = fp / (fp + tn)
    print(f"Tasa de Falsos Positivos para Clase {i} (FPR): {fpr_dict[f'Clase {i}']}")

# Curva ROC y AUC por clase
fpr = {}
tpr = {}
roc_auc = {}
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_val == i, y_pred[:, i])
    roc_auc[i] = roc_auc_score(y_val == i, y_pred[:, i])

# Plotear las curvas ROC para cada clase
plt.figure(figsize=(8, 6))
colors = ['blue', 'green', 'red', 'purple']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Clase %d (AUC = %0.2f)' % (i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR) o Sensibilidad')
plt.title('Curva ROC Multiclase')
plt.legend(loc="lower right")
plt.show()

# Precisión, Recall y F-Score para cada clase y promedio
precision = precision_score(y_val, y_pred_classes, average=None)
recall = recall_score(y_val, y_pred_classes, average=None)
f_score = f1_score(y_val, y_pred_classes, average=None)

print("Precisión por clase:", precision)
print("Recall por clase:", recall)
print("F-Score por clase:", f_score)

# Métricas promedio
precision_avg = precision_score(y_val, y_pred_classes, average='macro')
recall_avg = recall_score(y_val, y_pred_classes, average='macro')
f_score_avg = f1_score(y_val, y_pred_classes, average='macro')

print("Precisión promedio (macro):", precision_avg)
print("Recall promedio (macro):", recall_avg)
print("F-Score promedio (macro):", f_score_avg)
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# Matriz de Confusión:
# [[1498    0    0    0]
#  [   0 1561    0    0]
#  [   0    0 1461    0]
#  [   0    0    0 1548]]
# Tasa de Falsos Positivos para Clase 0 (FPR): 0.0
# Tasa de Falsos Positivos para Clase 1 (FPR): 0.0
# Tasa de Falsos Positivos para Clase 2 (FPR): 0.0
# Tasa de Falsos Positivos para Clase 3 (FPR): 0.0
# Precisión por clase: [1. 1. 1. 1.]
# Recall por clase: [1. 1. 1. 1.]
# F-Score por clase: [1. 1. 1. 1.]
# Precisión promedio (macro): 1.0
# Recall promedio (macro): 1.0
# F-Score promedio (macro): 1.0

# %%
print(X_test.shape)

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt

# Obtener las probabilidades de predicción
y_probs = model2.predict(X_test)

# Calcular la curva precision-recall y el área bajo la curva (AUC)
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
f1_scores = 2 * (precision * recall) / (precision + recall)
auc_score = auc(recall, precision)

# Graficar la curva F1-confidence
plt.figure(figsize=(8, 6))
plt.plot(thresholds, f1_scores[:-1], label='F1-score')
plt.xlabel('Threshold')
plt.ylabel('F1-score')
plt.title('F1-confidence Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_pred = loaded_model.predict(X_test)
# Convertir las probabilidades continuas en clases binarias usando umbral de 0.5
y_pred_bin = (loaded_model.predict(X_test) > 0.5).astype("int32")
# Obtener la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_bin)
print("Matriz de Confusión:")
#print(conf_matrix)
# Definir etiquetas para los ejes
labels = ["Negativo (0)", "Positivo (1)"]

# Crear el heatmap de la matriz de confusión
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)  # Ajustar el tamaño de fuente para mejor legibilidad
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicción")
plt.ylabel("Valor Real")
plt.title("Matriz de Confusión")
plt.show()
# Calcular otras métricas de evaluación
report = classification_report(y_test, y_pred_bin)

# Mostrar las métricas de evaluación
print("\nMétricas de Evaluación:")
print(report)
